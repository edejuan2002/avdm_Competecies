# %% [markdown]
# # Catalunya, administrative division
# ## **This notebook outputs a shp map of Catalonia that is necessary for other notebooks**
# The new website where download the data is: https://www.icgc.cat/ca/Geoinformacio-i-mapes/Dades-i-productes/Geoinformacio-cartografica/Divisions-administratives. Unzip the .shp data and create a folder inside data with the files.

# %%
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt
import pprint

import os
 
# Get the list of all shp files in BCN500 directory
dir_list_cat = [x for x in os.listdir("../data/divisions-administratives/") if x[-4:]==".shp"]
# first number: resolution/ scale, second number: Date

# %%
# list only highest resolution
dir_list_cat = [x for x in os.listdir("../data/divisions-administratives/") if x[-21:]=="-1000000-20240705.shp"]

# %%
ids = {x:x[31:-21] for x in dir_list_cat}
# ids

# %% [markdown]
# We want to compare the regions the 'Competencies' data set provides with this maps. The data set had the following separation:
#
# * Lleida &#8594; Lleida  (Provincia)
# * Tarragona &#8594; Camp de Tarragona (Vegueria)
# * Terres de l'Ebre &#8594; Terres de l'Ebre (Vegeria)
# * Vallés Occidental &#8594; (comarca)
# * Vallés Oriental + Maresme &#8594; (comarca)
# * Girona &#8594; (Provincia)
# * Catalunya central &#8594; (Comarca)
# * Barcelona Comarques (the rest)
# * Consocri BCN &#8594; municipi
#
# So each 'municipi' in cat_maps must have the code of these regions

# %%
# We select only the municipis map
cat_maps = {}
maps = dir_list_cat[1]
cat_maps[ids[maps]] = gpd.read_file("../data/divisions-administratives/"+maps, crs="EPSG:4326")
mncps = cat_maps[ids[maps]]

print(mncps.columns)


mncps['NOMREGIO'] = ""

# We build the regions that the Competencies data set uses
mncps.loc[mncps["NOMPROV"] == "Lleida", "NOMREGIO"] = "Lleida"
mncps.loc[mncps["NOMPROV"] == "Girona", "NOMREGIO"] = "Girona"
mncps.loc[mncps["NOMPROV"] == "Tarragona", "NOMREGIO"] = "Tarragona"
mncps.loc[mncps["NOMPROV"] == "Barcelona", "NOMREGIO"] = "Barcelona Comarques"

mncps.loc[mncps["NOMVEGUE"] == "Terres de l'Ebre", "NOMREGIO"] = "Terres de l'Ebre"
mncps.loc[mncps["NOMVEGUE"] == "Catalunya Central", "NOMREGIO"] = "Catalunya Central"

mncps.loc[mncps["NOMCOMAR"] == "Vallès Occidental", "NOMREGIO"] = "Vallès Occidental"
mncps.loc[mncps["NOMCOMAR"] == "Vallès Oriental", "NOMREGIO"] = "Maresme - Vallès Oriental"
mncps.loc[mncps["NOMCOMAR"] == "Maresme", "NOMREGIO"] = "Maresme - Vallès Oriental"
mncps.loc[mncps["NOMCOMAR"] == "Selva", "NOMREGIO"] = "Maresme - Vallès Oriental"

mncps.loc[mncps["NOMCOMAR"] == "Baix Llobregat", "NOMREGIO"] = "Baix Llobregat"

mncps.loc[mncps["NOMCOMAR"] == "Barcelonès", "NOMREGIO"] = "Consorci d'Educació de Barcelona"

# display(mncps.loc[mncps.index[10]:mncps.index[10]])
# Out:
# Index(['CODICOMAR', 'NOMCOMAR', 'CAPCOMAR', 'AREAC5000', 'geometry'], dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NOMPROV'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 13
#      10 mncps['NOMREGIO'] = ""
#      12 # We build the regions that the Competencies data set uses
# ---> 13 mncps.loc[mncps["NOMPROV"] == "Lleida", "NOMREGIO"] = "Lleida"
#      14 mncps.loc[mncps["NOMPROV"] == "Girona", "NOMREGIO"] = "Girona"
#      15 mncps.loc[mncps["NOMPROV"] == "Tarragona", "NOMREGIO"] = "Tarragona"
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\geopandas\geodataframe.py:1474, in GeoDataFrame.__getitem__(self, key)
#    1468 def __getitem__(self, key):
#    1469     """
#    1470     If the result is a column containing only 'geometry', return a
#    1471     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1472     return a GeoDataFrame.
#    1473     """
# -> 1474     result = super().__getitem__(key)
#    1475     # Custom logic to avoid waiting for pandas GH51895
#    1476     # result is not geometry dtype for multi-indexes
#    1477     if (
#    1478         pd.api.types.is_scalar(key)
#    1479         and key == ""
#    (...)
#    1482         and not is_geometry_type(result)
#    1483     ):
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'NOMPROV'

# %%
# Plot the map
fig, ax = plt.subplots(figsize=(10, 10))
mncps.plot(column='NOMREGIO', ax=ax, legend=True, cmap='tab20', legend_kwds={'loc': 'lower right'})

# Customize the plot
plt.title('Map of Municipalities Differentiated by NOMREGIO')
plt.axis('off')  # Turn off the axes
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NOMREGIO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Plot the map
#       2 fig, ax = plt.subplots(figsize=(10, 10))
# ----> 3 mncps.plot(column='NOMREGIO', ax=ax, legend=True, cmap='tab20', legend_kwds={'loc': 'lower right'})
#       5 # Customize the plot
#       6 plt.title('Map of Municipalities Differentiated by NOMREGIO')
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\geopandas\plotting.py:979, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     977 kind = kwargs.pop("kind", "geo")
#     978 if kind == "geo":
# --> 979     return plot_dataframe(data, *args, **kwargs)
#     980 if kind in self._pandas_kinds:
#     981     # Access pandas plots
#     982     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\geopandas\plotting.py:740, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     738             values = values.reindex(df.index)
#     739 else:
# --> 740     values = df[column]
#     742 if isinstance(values.dtype, CategoricalDtype):
#     743     if categories is not None:
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\geopandas\geodataframe.py:1474, in GeoDataFrame.__getitem__(self, key)
#    1468 def __getitem__(self, key):
#    1469     """
#    1470     If the result is a column containing only 'geometry', return a
#    1471     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1472     return a GeoDataFrame.
#    1473     """
# -> 1474     result = super().__getitem__(key)
#    1475     # Custom logic to avoid waiting for pandas GH51895
#    1476     # result is not geometry dtype for multi-indexes
#    1477     if (
#    1478         pd.api.types.is_scalar(key)
#    1479         and key == ""
#    (...)
#    1482         and not is_geometry_type(result)
#    1483     ):
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'NOMREGIO'

# %%
# Create a new GeoDataFrame by dissolving based on NOMREGIO
aggregated_regions = mncps.dissolve(by="NOMREGIO")

# Keep only the NOMREGIO and geometry columns in the new GeoDataFrame
aggregated_regions = aggregated_regions.reset_index()[["NOMREGIO", "geometry"]]

# Plot the aggregated regions
fig, ax = plt.subplots(figsize=(10, 10))
aggregated_regions.plot(ax=ax, color='lightblue', edgecolor='black')

# Customize the plot
plt.title('Aggregated Regions by NOMREGIO')
plt.axis('off')  # Hide axes for better visualization
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Create a new GeoDataFrame by dissolving based on NOMREGIO
# ----> 2 aggregated_regions = mncps.dissolve(by="NOMREGIO")
#       4 # Keep only the NOMREGIO and geometry columns in the new GeoDataFrame
#       5 aggregated_regions = aggregated_regions.reset_index()[["NOMREGIO", "geometry"]]
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\geopandas\geodataframe.py:1792, in GeoDataFrame.dissolve(self, by, aggfunc, as_index, level, sort, observed, dropna, **kwargs)
#    1790 data = self.drop(labels=self.geometry.name, axis=1)
#    1791 with warnings.catch_warnings(record=True) as record:
# -> 1792     aggregated_data = data.groupby(**groupby_kwargs).agg(aggfunc, **kwargs)
#    1793 for w in record:
#    1794     if str(w.message).startswith("The default value of numeric_only"):
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\pandas\core\groupby\groupby.py:1278, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1275 self.dropna = dropna
#    1277 if grouper is None:
# -> 1278     grouper, exclusions, obj = get_grouper(
#    1279         obj,
#    1280         keys,
#    1281         axis=axis,
#    1282         level=level,
#    1283         sort=sort,
#    1284         observed=False if observed is lib.no_default else observed,
#    1285         dropna=self.dropna,
#    1286     )
#    1288 if observed is lib.no_default:
#    1289     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\analysis-and-visualization-of-big-data-course\venv\Lib\site-packages\pandas\core\groupby\grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: 'NOMREGIO'

# %% [markdown]
# ## Saving and reloading
# **THIS CELL IS THE IMPORTANT ONE**

# %%
# Save the mncps map with the new column
mncps.to_file("../data/Municipis/mncps.shp", driver="ESRI Shapefile")
aggregated_regions.to_file("../data/Municipis/regions.shp", driver="ESRI Shapefile")

# %%
# You can reload it with
mncps = gpd.read_file("../data/Municipis/mncps.shp")

# %%
# This is just playing around

maps = dir_list_cat[2]
cat_maps[ids[maps]] = gpd.read_file("../data/divisions-administratives/"+maps, crs="EPSG:4326")
mncps = cat_maps[ids[maps]]


maps = dir_list_cat[3]
cat_maps[ids[maps]] = gpd.read_file("../data/divisions-administratives/"+maps, crs="EPSG:4326")
prvncs = cat_maps[ids[maps]]
# Plot both layers on the same axes
fig, ax = plt.subplots(figsize=(5, 5))

# Plot municipalities with one color and transparency
mncps.plot(ax=ax, color='lightblue', edgecolor='blue', linewidth=0.5, alpha=0.5, label="Municipalities")

# Plot provinces with a different color and transparency
prvncs.plot(ax=ax, color='none', edgecolor='red', linewidth=1.2, alpha=0.7, label="Provinces")

# Customize and show the plot
plt.title("Overlay of Provinces and Municipalities in Catalonia")
plt.show()
